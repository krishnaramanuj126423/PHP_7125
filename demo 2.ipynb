# %%
import pandas as pd
import numpy as np

# %%
marks_df = pd.DataFrame([
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,70,14],
    [80,70,14]
],columns=['iq','marks','package'])

marks_df
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14
# 4   80     70       14

# %%
# value_counts(): Returns the frequency of the value

marks_df.marks.value_counts()
# Out:
# marks
# 70     3
# 80     1
# 100    1
# Name: count, dtype: int64

# %%
marks_df.value_counts()
# Out:
# iq   marks  package
# 80   70     14         2
# 90   70     7          1
# 100  80     10         1
# 120  100    14         1
# Name: count, dtype: int64

# %%
# Find which player has won maximum no_of player_of_match award in final and qualifiers.


ipl[
    (ipl['MatchNumber'] == 'Final') |
    (ipl['MatchNumber'] == 'Qualifier 1')|
    (ipl['MatchNumber'] == 'Qualifier 2')
]  ['Player_of_Match'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 # Find which player has won maximum no_of player_of_match award in final and qualifiers.
# ----> 4 ipl[
#       5     (ipl['MatchNumber'] == 'Final') |
#       6     (ipl['MatchNumber'] == 'Qualifier 1')|
#       7     (ipl['MatchNumber'] == 'Qualifier 2')
#       8 ]  ['Player_of_Match'].value_counts()
#
# NameError: name 'ipl' is not defined

# %%
# sort_values()

s = pd.Series([1, 5, 7, 9, 5, 3, 4, 6, 2, 8])


s.sort_values(ascending = False)
# Out:
# 3    9
# 9    8
# 2    7
# 7    6
# 1    5
# 4    5
# 6    4
# 5    3
# 8    2
# 0    1
# dtype: int64

# %%
ipl.sort_values(by = 'City')
# Out:
#           ID       City        Date   Season  MatchNumber  \
# 135  1237180  Abu Dhabi  2020-11-08  2020/21  Qualifier 2
# 95   1254098  Abu Dhabi  2021-09-26     2021           38
# 533   729315  Abu Dhabi  2014-04-29     2014           19
# 181  1216503  Abu Dhabi  2020-10-01  2020/21           13
# 92   1254099  Abu Dhabi  2021-09-28     2021           42
# ..       ...        ...         ...      ...          ...
# 543   729295        NaN  2014-04-22     2014            9
# 545   729291        NaN  2014-04-20     2014            7
# 546   729289        NaN  2014-04-19     2014            6
# 547   729287        NaN  2014-04-19     2014            5
# 550   729281        NaN  2014-04-17     2014            2
#
#                            Team1                        Team2  \
# 135               Delhi Capitals          Sunrisers Hyderabad
# 95         Kolkata Knight Riders          Chennai Super Kings
# 533        Kolkata Knight Riders             Rajasthan Royals
# ...

# %%
# rank():
# It ranks based on value.
# Remember, the one with the highest value, receives the lowest rank

batsman = pd.read_csv(r"D:\Nikss\Self Pracitce\Python from beginning (CampusX)\18 Session 18 - (DataFrame Methods)/00 batsman_runs_ipl.csv")
batsman
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
batsman['batsman_run'].rank(ascending = False)
# Out:
# 0      166.5
# 1      226.0
# 2      535.0
# 3      329.0
# 4      402.5
#        ...
# 600    594.0
# 601    343.0
# 602    547.5
# 603     27.0
# 604    256.0
# Name: batsman_run, Length: 605, dtype: float64

# %%
# rename(): Renames the columns

students = pd.DataFrame(
    {
        'name':['nitish','ankit','rupesh','harshit','mrityunjay','jenish','rishabh','parth','aditya','khilan'],
        'college':['bit','iit','vit','gmers','psmc','vlsi','ssit','ld','gsms','git'],
        'branch':['eee','it','cse','mbbs','me','ce','civ','cse','bio','mba'],
        'cgpa':[6.66,8.25,6.41,8,5.6,9.0,7.4,10,7.4,7.8],
        'package':[4,5,6,10,6,7,8,9,11,9.5]

    }
)

students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3     harshit   gmers   mbbs   8.00     10.0
# 4  mrityunjay    psmc     me   5.60      6.0
# 5      jenish    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7       parth      ld    cse  10.00      9.0
# 8      aditya    gsms    bio   7.40     11.0
# 9      khilan     git    mba   7.80      9.5

# %%
cols = {'name': 'student', 'college': 'institute'}

students.rename(columns=cols)
# Out:
#       student institute branch   cgpa  package
# 0      nitish       bit    eee   6.66      4.0
# 1       ankit       iit     it   8.25      5.0
# 2      rupesh       vit    cse   6.41      6.0
# 3     harshit     gmers   mbbs   8.00     10.0
# 4  mrityunjay      psmc     me   5.60      6.0
# 5      jenish      vlsi     ce   9.00      7.0
# 6     rishabh      ssit    civ   7.40      8.0
# 7       parth        ld    cse  10.00      9.0
# 8      aditya      gsms    bio   7.40     11.0
# 9      khilan       git    mba   7.80      9.5

# %%
# unique(): Will return the unique values

data = pd.Series([1, 2, 3, 4, 5, 1, 2, 5, 55, 45, 65, 75, np.nan, np.nan, np.nan])

data.unique()
# Out:
# array([ 1.,  2.,  3.,  4.,  5., 55., 45., 65., 75., nan])

# %%
ipl['Season'].unique()
# Out:
# array(['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08'],
#       dtype=object)

# %%
# nunique(): Returns the no_of unique values. It doesn't count null values

data
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3      4.0
# 4      5.0
# 5      1.0
# 6      2.0
# 7      5.0
# 8     55.0
# 9     45.0
# 10    65.0
# 11    75.0
# 12     NaN
# 13     NaN
# 14     NaN
# dtype: float64

# %%
data.nunique()
# Out:
# 9

# %%
ipl['Season'].nunique()
# Out:
# 15

# %%
# isnull(): This returns True if the value in null else False

ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl.isnull()
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0         False         False      False        False  False   False    True
# ...

# %%
ipl['method']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 945    NaN
# 946    NaN
# 947    NaN
# 948    NaN
# 949    NaN
# Name: method, Length: 950, dtype: object

# %%
# dropna(): This drops the null values

len(ipl)
# Out:
# 950

# %%
ipl.dropna(inplace= True)

# %%
len(ipl)
# Out:
# 19

# %%
# fillna(): Fills the null values

s = pd.Series([1, 2, 3, 4, 5, np.nan, 6, 7, np.nan, 8, 9])
s
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     5.0
# 5     NaN
# 6     6.0
# 7     7.0
# 8     NaN
# 9     8.0
# 10    9.0
# dtype: float64

# %%
s.fillna(100)
# Out:
# 0       1.0
# 1       2.0
# 2       3.0
# 3       4.0
# 4       5.0
# 5     100.0
# 6       6.0
# 7       7.0
# 8     100.0
# 9       8.0
# 10      9.0
# dtype: float64

# %%
# dropduplicates(): Deletes the duplicate rows

data = {
    'Name': ['Nikunj', 'Jugal', 'Harshit', 'Jenish', 'Jugal', 'Harshit', 'Parth', 'Jenish', 'Parth'],
    'Surname': ['Bosamiya', 'Bosamiya', 'Kamani', 'Mer', 'Bosamiya', 'Kamani', 'Paghdar', 'Mer', 'Paghdar'],
    'City': ['Jetpur', 'Rajkot', 'Himmatnagar', 'Anand', 'Rajkot', 'Himmatnagar', 'Jetpur', 'Ahmedabad', 'Vadodara']
}

friends = pd.DataFrame(data)

friends
# Out:
#       Name   Surname         City
# 0   Nikunj  Bosamiya       Jetpur
# 1    Jugal  Bosamiya       Rajkot
# 2  Harshit    Kamani  Himmatnagar
# 3   Jenish       Mer        Anand
# 4    Jugal  Bosamiya       Rajkot
# 5  Harshit    Kamani  Himmatnagar
# 6    Parth   Paghdar       Jetpur
# 7   Jenish       Mer    Ahmedabad
# 8    Parth   Paghdar     Vadodara

# %%
friends.drop_duplicates()
# Out:
#       Name   Surname         City
# 0   Nikunj  Bosamiya       Jetpur
# 1    Jugal  Bosamiya       Rajkot
# 2  Harshit    Kamani  Himmatnagar
# 3   Jenish       Mer        Anand
# 6    Parth   Paghdar       Jetpur
# 7   Jenish       Mer    Ahmedabad
# 8    Parth   Paghdar     Vadodara
